# %%
import matplotlib.pylab as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from fcmpy.ml.classification.eltcn import run
import matplotlib.pylab as plt
import decimal

# %%
def float_to_decimal(x):
    return decimal.Decimal(str(x))

def read_csv_data(path):
    df = pd.read_csv(path,  converters={"c1": float_to_decimal, "c2": float_to_decimal, "c3": float_to_decimal,"c4": float_to_decimal,"c5": float_to_decimal,"c6": float_to_decimal,"c7": float_to_decimal,"c8": float_to_decimal,"c9": float_to_decimal,"c10": float_to_decimal,"c11": float_to_decimal,"c12": float_to_decimal,"c13": float_to_decimal,"c14": float_to_decimal,"c15": float_to_decimal,"c16": float_to_decimal})
    return df

# %%
#import dataset
dengue_data = read_csv_data('student.csv')

#output vector
y = dengue_data.c16


#input vector
x = dengue_data.drop('c16',axis=1)


#split 
x_train,x_test,y_train,y_test=train_test_split(x ,y, test_size=0.3, random_state=1)

x_train.to_csv('train-student_xdata.csv', index=False)
x_test.to_csv('test-student_xdata.csv', index=False)
y_test.to_csv('test-student_ydata.csv', index=False)
y_train.to_csv('train-student_ydata.csv', index=False)

concatenated_train = pd.concat([x_train, y_train], axis="columns")
print(concatenated_train)
concatenated_train.to_csv('train_student_final_data.csv', index=False)


concatenated_test = pd.concat([x_test, y_test], axis="columns")
print(concatenated_test)
concatenated_test.to_csv('test_student_final_data.csv', index=False)

#verify

#sources = ['raw_data.arff']
#params = {'sources':sources}

#out = run('data')
#fig, ax = plt.subplots()
#ax.bar(range(len(out[0]['importance'].flatten())), height=out[0]['importance'].flatten())

#out[0]['weights']

#print(out['iris.arff']['avgW'])

#print(out['iris.arff']['classW'])
# Out:
#       c1                   c2   c3                  c4   c5  \
# 103  0.0   0.8461538461538463  0.5                 0.0  1.0
# 544  0.0   0.8461538461538463  0.0  1.0000000000000002  0.0
# 146  1.0  0.38461538461538464  1.0                 0.5  0.0
# 335  0.0   0.3076923076923077  0.5                 0.0  0.0
# 638  0.0   0.8461538461538463  0.5                 0.0  1.0
# ..   ...                  ...  ...                 ...  ...
# 144  0.0   0.8461538461538463  1.0                 0.5  0.0
# 645  1.0   0.8461538461538463  0.0  1.0000000000000002  0.0
# 72   0.0   0.8461538461538463  1.0                 0.5  0.0
# 235  0.0   0.8461538461538463  1.0                 0.5  1.0
# 37   1.0  0.23076923076923078  1.0                 0.5  0.0
#
#                      c6   c7   c8    c9                   c10  \
# 103  0.4545454545454545  1.0  0.0  0.01   0.07070707070707072
# 544  0.6363636363636364  1.0  0.0  0.13   0.05050505050505051
# 146  0.1818181818181818  0.0  1.0   1.0    0.7575757575757577
# 335  0.5454545454545454  0.0  1.0  0.15   0.07070707070707072
# 638  0.4545454545454545  1.0  0.0  0.07   0.05050505050505051
# ..                  ...  ...  ...   ...                   ...
# 144  0.1818181818181818  0.0  0.0   0.1   0.10101010101010102
# 645  0.6363636363636364  1.0  0.0   0.2   0.14141414141414144
# 72   0.9090909090909091  1.0  0.0  0.11  0.020202020202020204
# 235  0.2727272727272727  0.0  0.0  0.12   0.08080808080808081
# 37   0.4545454545454545  1.0  0.0  0.45    0.5454545454545455
#
#                       c11                   c12  c13  c14  c15  c16
# 103  0.061224489795918366   0.09183673469387754  0.0  0.0  1.0  0.0
# 544   0.18367346938775508   0.18367346938775508  0.0  0.0  1.0  0.0
# 146    0.5102040816326531    0.7040816326530611  1.0  1.0  0.0  1.0
# 335   0.12244897959183673  0.061224489795918366  0.0  1.0  1.0  0.0
# 638   0.02040816326530612    0.8061224489795917  1.0  1.0  1.0  0.0
# ..                    ...                   ...  ...  ...  ...  ...
# 144    0.1530612244897959   0.18367346938775508  0.0  0.0  1.0  0.0
# 645   0.12244897959183673    0.7040816326530611  0.0  0.0  1.0  0.0
# 72    0.02040816326530612   0.07142857142857142  0.0  0.0  0.0  0.0
# 235   0.18367346938775508    0.2551020408163265  0.0  0.0  1.0  0.0
# 37    0.26530612244897955    0.9081632653061223  1.0  1.0  0.0  1.0
#
# [494 rows x 16 columns]
#       c1                  c2   c3                  c4   c5  \
# 605  0.0  0.8461538461538463  1.0  0.6000000000000001  0.0
# 425  1.0  0.5384615384615385  1.0  0.6000000000000001  0.0
# 334  0.0  0.3076923076923077  0.5                 0.0  0.0
# 457  1.0  0.5384615384615385  1.0  0.6000000000000001  0.0
# 187  1.0  0.8461538461538463  1.0  0.6000000000000001  0.0
# ..   ...                 ...  ...                 ...  ...
# 628  1.0  0.8461538461538463  0.5                 0.5  0.0
# 160  1.0  0.5384615384615385  1.0                 0.5  1.0
# 449  0.0  0.5384615384615385  1.0  0.6000000000000001  0.0
# 305  1.0  0.5384615384615385  0.5                 0.2  1.0
# 584  0.0  0.8461538461538463  1.0                 0.5  1.0
#
#                       c6   c7   c8                  c9                   c10  \
# 605   0.7272727272727273  0.0  0.0                0.15   0.25252525252525254
# 425  0.09090909090909091  0.0  1.0                0.84    0.7777777777777778
# 334   0.5454545454545454  1.0  1.0                 0.1   0.08080808080808081
# 457   0.8181818181818182  0.0  0.0                0.79    0.9191919191919192
# 187   0.7272727272727273  0.0  0.0                 0.8    0.7171717171717172
# ..                   ...  ...  ...                 ...                   ...
# 628   0.4545454545454545  1.0  0.0                0.02   0.19191919191919193
# 160   0.2727272727272727  0.0  1.0  0.8200000000000001    0.8989898989898991
# 449   0.9999999999999999  0.0  1.0                0.81    0.8484848484848485
# 305   0.2727272727272727  0.0  0.0                0.32    0.4444444444444445
# 584   0.4545454545454545  1.0  0.0                 0.0  0.020202020202020204
#
#                       c11                   c12  c13  c14  c15  c16
# 605   0.37755102040816324   0.12244897959183672  1.0  1.0  1.0  0.0
# 425    0.8061224489795917    0.6836734693877551  1.0  1.0  0.0  1.0
# 334   0.09183673469387754  0.020408163265306124  0.0  1.0  1.0  0.0
# 457   0.49999999999999994   0.21428571428571425  1.0  1.0  0.0  1.0
# 187    0.5306122448979591     0.510204081632653  1.0  1.0  0.0  1.0
# ..                    ...                   ...  ...  ...  ...  ...
# 628    0.1020408163265306                   0.5  1.0  1.0  1.0  0.0
# 160    0.5918367346938775                   0.5  1.0  1.0  0.0  1.0
# 449    0.7857142857142857    0.8571428571428571  1.0  1.0  0.0  1.0
# 305   0.29591836734693877    0.8979591836734693  1.0  0.0  0.0  1.0
# 584  0.030612244897959183    0.7040816326530611  1.0  1.0  1.0  0.0
#
# [212 rows x 16 columns]
